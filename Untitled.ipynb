# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://www.currentresults.com/Weather/US/average-annual-state-precipitation.php'
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="/Css-RD/main-rd-jun11-18.css" rel="stylesheet"/>
#   <link href="/Css-RD/mediaq-rd-jun8-18.css" media="only screen and (min-width: 29em) " rel="stylesheet"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/touch-icon-192x192.png" rel="icon" sizes="192x192"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="#0A8BDF" name="theme-color"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1038710-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1038710-1', { 'anonymize_ip': true });
#   </script>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-8496941113728804",
#           enable_page_level_ads: true
#      });
#   </script>
#   <title>
#    Average Annual Precipitation by USA State - Current Results
#   </title>
#   <meta content="Map and data give the average annual precipitation for each American state, plus states are ranked from wettest to driest. " name="description">
#   </meta>
#  </head>
#  <body>
#   <div id="container">
#    <a href="#top">
#    </a>
#    <div class="banner">
#     <a href="#mm">
#      <div class="menu-navicon shadow">
#       <div class="menu-text">
#        Menu
#       </div>
#      </div>
#     </a>
#     <a href="#ms">
#      <div class="menu-navicon search-navicon shadow">
#      </div>
#     </a>
#     <div class="centername">
#      <p class="title">
#       <a href="/index.php">
#        <span class="firstletter">
#         C
#        </span>
#        urrent
#        <span class="firstletter">
#         R
#        </span>
#        esults
#       </a>
#      </p>
#      <p class="tag">
#       weather and science facts
#      </p>
#     </div>
#     <div class="rwdsearch">
#      <script>
#       (function() {
#     var cx = 'partner-pub-8496941113728804:5136326527';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +
#          '//cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#      </script>
#      <gcse:searchbox-only>
#      </gcse:searchbox-only>
#     </div>
#    </div>
#    <div class="navbar">
#     <ul>
#      <li>
#       <a href="/index.php">
#        Home
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#      <li>
#       <a href="/Weather-Extremes/index.php">
#        Weather Extremes
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#      <li>
#       <a href="/Weather/index.php">
#        Weather Averages
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#      <li>
#       <a href="/Weather/US/weather-averages-index.php">
#        USA
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#      <li>
#       <a href="/Weather/Canada/weather-averages-index.php">
#        Canada
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#      <li>
#       <a href="/Weather/Europe/Cities/average-european-city-weather.php">
#        Europe
#       </a>
#      </li>
#      <li class="divider">
#       |
#      </li>
#     </ul>
#    </div>
#    <!--[if lt IE 10]>
# <p class="ifltie10">This page doesn't display properly in Internet Explorer 9, 8 or older. Please view it in a different browser.</p>
# <![endif]-->
#    <div id="maincol">
#     <h1>
#      Average Annual Precipitation by State
#     </h1>
#     <div class="article">
#      <div class="ad-blwttl-rec">
#       <style>
#        .cr-1d-rd-blwttl-desk-rec-dkbl { display:none; }
# @media(min-width: 525px) { .cr-1d-rd-blwttl-desk-rec-dkbl { display: inline-block; width: 300px; height: 250px; } }
# @media(min-width: 688px) { .cr-1d-rd-blwttl-desk-rec-dkbl { width: 336px; height: 280px; } }
#       </style>
#       <ins <="" class="adsbygoogle cr-1d-rd-blwttl-desk-rec-dkbl" data-ad-client="ca-pub-8496941113728804" data-ad-slot="3681648122" ins="">
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </ins>
#      </div>
#      <div class="addthis-top-vertical">
#       <div class="addthis_toolbox addthis_default_style addthis_20x20_style">
#        <a class="addthis_button_preferred_1">
#        </a>
#        <br/>
#        <a class="addthis_button_preferred_2" style="margin-top: 4px;">
#        </a>
#        <br/>
#        <a class="addthis_button_preferred_3" style="margin-top: 4px;">
#        </a>
#        <br/>
#        <a class="addthis_button_preferred_4" style="margin-top: 4px;">
#        </a>
#        <br/>
#        <a class="addthis_button_compact" style="margin-top: 4px;">
#        </a>
#       </div>
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=wildland">
#       </script>
#      </div>
#      <p>
#       How much precipitation each state in the US gets on average in a year is listed below. The states are also ranked from the wettest state at number 1, to the driest state at number 50.
#      </p>
#      <p>
#       Below the tables there's a map that allows you to visually compare the annual average precipitation totals among states.
#      </p>
#      <div class="ad-mobile-rec">
#       <style>
#        .cr-1m-rd-atfld-mobe-medrec-dkbl { display:inline-block; width: 320px; height: 100px; }
# @media(min-width: 525px) { .cr-1m-rd-atfld-mobe-medrec-dkbl { display: none; } }
#       </style>
#       <ins <="" class="adsbygoogle cr-1m-rd-atfld-mobe-medrec-dkbl" data-ad-client="ca-pub-8496941113728804" data-ad-slot="6635114526" data-full-width-responsive="true" ins="">
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </ins>
#      </div>
#      <p>
#       State-wide averages of annual rainfall plus snowfall range from a high of 63.7 inches (1618 millimetres) in Hawaii to a low of 9.5 inches (241 millimetres) in Nevada. For the entire United States, excluding Hawaii and Alaska, the average amount of moisture falling as rain and snow is 30.21 inches (767 millimetres).
#      </p>
#      <p>
#       The precipitation averages are based on data collected by weather stations throughout each state from 1971 to 2000 and provided by the
#       <a href="http://www.ncdc.noaa.gov/oa/ncdc.html" target="_blank">
#        NOAA National Climatic Data Center
#       </a>
#       .
#      </p>
#      <p>
#       State names are linked to more detailed rain and snow information for that state.
#      </p>
#      <div class="clearboth">
#       <table class="articletable tablecol-1-left">
#        <caption>
#         Average total yearly precipitation for each state.
#        </caption>
#        <thead>
#         <tr>
#          <th>
#           State
#          </th>
#          <th>
#           Inches
#          </th>
#          <th>
#           Milli­metres
#          </th>
#          <th>
#           Rank
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td>
#           <a href="/Weather/Alabama/average-yearly-precipitation.php">
#            Alabama
#           </a>
#          </td>
#          <td>
#           58.3
#          </td>
#          <td>
#           1480
#          </td>
#          <td>
#           4
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Alaska/average-yearly-precipitation.php">
#            Alaska
#           </a>
#          </td>
#          <td>
#           22.5
#          </td>
#          <td>
#           572
#          </td>
#          <td>
#           39
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Arizona/yearly-average-precipitation.php">
#            Arizona
#           </a>
#          </td>
#          <td>
#           13.6
#          </td>
#          <td>
#           345
#          </td>
#          <td>
#           47
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Arkansas/average-yearly-precipitation.php">
#            Arkansas
#           </a>
#          </td>
#          <td>
#           50.6
#          </td>
#          <td>
#           1284
#          </td>
#          <td>
#           8
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/California/average-yearly-city-precipitation.php">
#            California
#           </a>
#          </td>
#          <td>
#           22.2
#          </td>
#          <td>
#           563
#          </td>
#          <td>
#           40
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Colorado/average-yearly-precipitation.php">
#            Colorado
#           </a>
#          </td>
#          <td>
#           15.9
#          </td>
#          <td>
#           405
#          </td>
#          <td>
#           44
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Connecticut/average-yearly-precipitation.php">
#            Connecticut
#           </a>
#          </td>
#          <td>
#           50.3
#          </td>
#          <td>
#           1279
#          </td>
#          <td>
#           9
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Delaware/annual-weather-averages.php">
#            Delaware
#           </a>
#          </td>
#          <td>
#           45.7
#          </td>
#          <td>
#           1160
#          </td>
#          <td>
#           16
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Florida/yearly-florida-rainfall.php">
#            Florida
#           </a>
#          </td>
#          <td>
#           54.5
#          </td>
#          <td>
#           1385
#          </td>
#          <td>
#           5
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Georgia/average-yearly-precipitation.php">
#            Georgia
#           </a>
#          </td>
#          <td>
#           50.7
#          </td>
#          <td>
#           1287
#          </td>
#          <td>
#           7
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Hawaii/yearly-rainfall.php">
#            Hawaii
#           </a>
#          </td>
#          <td>
#           63.7
#          </td>
#          <td>
#           1618
#          </td>
#          <td>
#           1
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Idaho/average-yearly-precipitation.php">
#            Idaho
#           </a>
#          </td>
#          <td>
#           18.9
#          </td>
#          <td>
#           481
#          </td>
#          <td>
#           42
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Illinois/average-yearly-precipitation.php">
#            Illinois
#           </a>
#          </td>
#          <td>
#           39.2
#          </td>
#          <td>
#           996
#          </td>
#          <td>
#           27
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Indiana/average-yearly-precipitation.php">
#            Indiana
#           </a>
#          </td>
#          <td>
#           41.7
#          </td>
#          <td>
#           1060
#          </td>
#          <td>
#           26
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Iowa/average-yearly-precipitation.php">
#            Iowa
#           </a>
#          </td>
#          <td>
#           34.0
#          </td>
#          <td>
#           864
#          </td>
#          <td>
#           31
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Kansas/average-yearly-precipitation.php">
#            Kansas
#           </a>
#          </td>
#          <td>
#           28.9
#          </td>
#          <td>
#           733
#          </td>
#          <td>
#           35
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Kentucky/average-yearly-precipitation.php">
#            Kentucky
#           </a>
#          </td>
#          <td>
#           48.9
#          </td>
#          <td>
#           1242
#          </td>
#          <td>
#           12
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="ad-mid-hor">
#        <ins class="adsbygoogle" data-ad-client="ca-pub-8496941113728804" data-ad-format="auto" data-ad-slot="7972246922" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#       <div class="clearboth padtop1em">
#       </div>
#       <table class="articletable tablecol-1-left">
#        <thead>
#         <tr>
#          <th>
#           State
#          </th>
#          <th>
#           Inches
#          </th>
#          <th>
#           Milli­metres
#          </th>
#          <th>
#           Rank
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td>
#           <a href="/Weather/Louisiana/average-yearly-precipitation.php">
#            Louisiana
#           </a>
#          </td>
#          <td>
#           60.1
#          </td>
#          <td>
#           1528
#          </td>
#          <td>
#           2
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Maine/average-yearly-precipitation.php">
#            Maine
#           </a>
#          </td>
#          <td>
#           42.2
#          </td>
#          <td>
#           1072
#          </td>
#          <td>
#           23
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Maryland/average-yearly-precipitation.php">
#            Maryland
#           </a>
#          </td>
#          <td>
#           44.5
#          </td>
#          <td>
#           1131
#          </td>
#          <td>
#           18
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Massachusetts/average-yearly-precipitation.php">
#            Massachusetts
#           </a>
#          </td>
#          <td>
#           47.7
#          </td>
#          <td>
#           1211
#          </td>
#          <td>
#           14
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Michigan/average-yearly-precipitation.php">
#            Michigan
#           </a>
#          </td>
#          <td>
#           32.8
#          </td>
#          <td>
#           833
#          </td>
#          <td>
#           32
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Minnesota/average-yearly-precipitation.php">
#            Minnesota
#           </a>
#          </td>
#          <td>
#           27.3
#          </td>
#          <td>
#           693
#          </td>
#          <td>
#           37
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Mississippi/average-yearly-precipitation.php">
#            Mississippi
#           </a>
#          </td>
#          <td>
#           59.0
#          </td>
#          <td>
#           1499
#          </td>
#          <td>
#           3
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Missouri/average-yearly-precipitation.php">
#            Missouri
#           </a>
#          </td>
#          <td>
#           42.2
#          </td>
#          <td>
#           1071
#          </td>
#          <td>
#           24
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Montana/average-yearly-precipitation.php">
#            Montana
#           </a>
#          </td>
#          <td>
#           15.3
#          </td>
#          <td>
#           390
#          </td>
#          <td>
#           45
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Nebraska/average-yearly-precipitation.php">
#            Nebraska
#           </a>
#          </td>
#          <td>
#           23.6
#          </td>
#          <td>
#           599
#          </td>
#          <td>
#           38
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Nevada/average-yearly-precipitation.php">
#            Nevada
#           </a>
#          </td>
#          <td>
#           9.5
#          </td>
#          <td>
#           241
#          </td>
#          <td>
#           50
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/New-Hampshire/average-yearly-precipitation.php">
#            New Hampshire
#           </a>
#          </td>
#          <td>
#           43.4
#          </td>
#          <td>
#           1103
#          </td>
#          <td>
#           20
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/New-Jersey/average-yearly-precipitation.php">
#            New Jersey
#           </a>
#          </td>
#          <td>
#           47.1
#          </td>
#          <td>
#           1196
#          </td>
#          <td>
#           15
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/New-Mexico/average-yearly-precipitation.php">
#            New Mexico
#           </a>
#          </td>
#          <td>
#           14.6
#          </td>
#          <td>
#           370
#          </td>
#          <td>
#           46
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/New-York/average-yearly-precipitation.php">
#            New York
#           </a>
#          </td>
#          <td>
#           41.8
#          </td>
#          <td>
#           1062
#          </td>
#          <td>
#           25
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/North-Carolina/average-yearly-precipitation.php">
#            North Carolina
#           </a>
#          </td>
#          <td>
#           50.3
#          </td>
#          <td>
#           1279
#          </td>
#          <td>
#           9
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/North-Dakota/average-yearly-precipitation.php">
#            North Dakota
#           </a>
#          </td>
#          <td>
#           17.8
#          </td>
#          <td>
#           452
#          </td>
#          <td>
#           43
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="ad-end-smart">
#        <ins class="adsbygoogle" data-ad-client="ca-pub-8496941113728804" data-ad-format="auto" data-ad-slot="3402446525" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#       <div class="clearboth padtop1em">
#       </div>
#       <table class="articletable tablecol-1-left">
#        <thead>
#         <tr>
#          <th>
#           State
#          </th>
#          <th>
#           Inches
#          </th>
#          <th>
#           Milli­metres
#          </th>
#          <th>
#           Rank
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td>
#           <a href="/Weather/Ohio/average-yearly-precipitation.php">
#            Ohio
#           </a>
#          </td>
#          <td>
#           39.1
#          </td>
#          <td>
#           993
#          </td>
#          <td>
#           28
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Oklahoma/average-yearly-precipitation.php">
#            Oklahoma
#           </a>
#          </td>
#          <td>
#           36.5
#          </td>
#          <td>
#           927
#          </td>
#          <td>
#           30
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Oregon/average-yearly-precipitation.php">
#            Oregon
#           </a>
#          </td>
#          <td>
#           27.4
#          </td>
#          <td>
#           695
#          </td>
#          <td>
#           36
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Pennsylvania/average-yearly-precipitation.php">
#            Pennsylvania
#           </a>
#          </td>
#          <td>
#           42.9
#          </td>
#          <td>
#           1089
#          </td>
#          <td>
#           21
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Rhode-Island/annual-weather-averages.php">
#            Rhode Island
#           </a>
#          </td>
#          <td>
#           47.9
#          </td>
#          <td>
#           1218
#          </td>
#          <td>
#           13
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/South-Carolina/average-yearly-precipitation.php">
#            South Carolina
#           </a>
#          </td>
#          <td>
#           49.8
#          </td>
#          <td>
#           1264
#          </td>
#          <td>
#           11
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/South-Dakota/average-yearly-precipitation.php">
#            South Dakota
#           </a>
#          </td>
#          <td>
#           20.1
#          </td>
#          <td>
#           511
#          </td>
#          <td>
#           41
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Tennessee/average-yearly-precipitation.php">
#            Tennessee
#           </a>
#          </td>
#          <td>
#           54.2
#          </td>
#          <td>
#           1376
#          </td>
#          <td>
#           6
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Texas/average-yearly-precipitation.php">
#            Texas
#           </a>
#          </td>
#          <td>
#           28.9
#          </td>
#          <td>
#           734
#          </td>
#          <td>
#           34
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Utah/average-yearly-precipitation.php">
#            Utah
#           </a>
#          </td>
#          <td>
#           12.2
#          </td>
#          <td>
#           310
#          </td>
#          <td>
#           49
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Vermont/average-yearly-precipitation.php">
#            Vermont
#           </a>
#          </td>
#          <td>
#           42.7
#          </td>
#          <td>
#           1085
#          </td>
#          <td>
#           22
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Virginia/average-yearly-precipitation.php">
#            Virginia
#           </a>
#          </td>
#          <td>
#           44.3
#          </td>
#          <td>
#           1125
#          </td>
#          <td>
#           19
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Washington/average-yearly-precipitation.php">
#            Washington
#           </a>
#          </td>
#          <td>
#           38.4
#          </td>
#          <td>
#           976
#          </td>
#          <td>
#           29
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/West-Virginia/average-yearly-precipitation.php">
#            West Virginia
#           </a>
#          </td>
#          <td>
#           45.2
#          </td>
#          <td>
#           1147
#          </td>
#          <td>
#           17
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Wisconsin/average-yearly-precipitation.php">
#            Wisconsin
#           </a>
#          </td>
#          <td>
#           32.6
#          </td>
#          <td>
#           829
#          </td>
#          <td>
#           33
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="/Weather/Wyoming/average-yearly-precipitation.php">
#            Wyoming
#           </a>
#          </td>
#          <td>
#           12.9
#          </td>
#          <td>
#           328
#          </td>
#          <td>
#           48
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <img alt="USA map of annual average state precipitation" height="454" src="/Images/Maps/usa-state-precipitation-year.jpg" width="560"/>
#      </div>
#     </div>
#     <div class="addthis-end">
#      <div class="addthis_toolbox addthis_default_style addthis_32x32_style">
#       <a class="addthis_button_compact">
#        Share
#       </a>
#       <a class="addthis_button_preferred_1" style="margin-right: 12px; margin-left: 10px;">
#       </a>
#       <a class="addthis_button_preferred_2" style="margin-right: 12px;">
#       </a>
#       <a class="addthis_button_preferred_3" style="margin-right: 12px;">
#       </a>
#       <a class="addthis_button_preferred_4" style="margin-right: 12px;">
#       </a>
#       <a class="addthis_button_preferred_5">
#       </a>
#      </div>
#     </div>
#     <div class="more">
#      <h4>
#       <a href="/Weather/US/average-state-weather.php">
#        More American State Weather Information
#       </a>
#      </h4>
#      <ul>
#       <li>
#        <a href="/Weather-Extremes/US/wettest-states.php">
#         Wettest States in America
#        </a>
#       </li>
#       <li>
#        <a href="/Weather-Extremes/US/driest-states.php">
#         Driest States in the US
#        </a>
#       </li>
#       <li>
#        <a href="/Weather/US/average-annual-state-temperatures.php">
#         Average Annual Temperatures by State
#        </a>
#       </li>
#       <li>
#        <a href="/Weather/US/average-annual-state-sunshine.php">
#         Average Yearly Sunshine for Each State
#        </a>
#       </li>
#       <li>
#        <a href="/Weather/US/average-snowfall-by-state.php">
#         Yearly Snowfall in Each State
#        </a>
#       </li>
#       <li>
#        <a href="/Weather/US/annual-average-humidity-by-state.php">
#         Annual Humidity Averages by State
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="leftcoltop">
#     <a name="mm">
#     </a>
#     <div class="lefttop-nav-breadstart">
#      <a href="/Weather/index.php">
#       Weather Averages
#      </a>
#     </div>
#     <p class="breadcrumbs">
#      <a href="/Weather/US/weather-averages-index.php">
#       USA
#      </a>
#      &gt;
#      <a href="/Weather/US/average-state-weather.php">
#       States
#      </a>
#      &gt;
#     </p>
#     <div class="lefttop-nav-category">
#      State Precipitation
#     </div>
#     <ul class="linklist">
#      <li>
#       <a href="/Weather/US/average-state-precipitation-in-spring.php">
#        Spring
#       </a>
#      </li>
#      <li>
#       <a href="/Weather/US/average-state-precipitation-in-summer.php">
#        Summer
#       </a>
#      </li>
#      <li>
#       <a href="/Weather/US/average-state-precipitation-in-fall.php">
#        Fall
#       </a>
#      </li>
#      <li>
#       <a href="/Weather/US/average-state-precipitation-in-winter.php">
#        Winter
#       </a>
#      </li>
#      <li>
#       <a href="/Weather/US/average-annual-state-precipitation.php">
#        Annual
#       </a>
#      </li>
#      <li>
#       <a href="/Weather/US/state-precipitation-maps-seasonal.php">
#        Seasonal Maps
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="narrownav">
#     <div class="narrow-nav-subcategory">
#      <a href="/Weather/US/average-city-weather.php">
#       Major USA Cities
#      </a>
#     </div>
#     <ul>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-temperatures-large-cities.php">
#        Temperature
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-precipitation-by-city.php">
#        Precipitation
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/annual-snowfall-by-city.php">
#        Snow
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-sunshine-by-city.php">
#        Sun
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/humidity-city-annual.php">
#        Humidity
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/wind-speed-city-annual.php">
#        Wind
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Yearly-Weather/USA/recent-yearly-weather-usa-cities-index.php">
#        Recent
#       </a>
#      </li>
#     </ul>
#     <div class="narrow-nav-subcategory">
#      <a href="/Weather/US/weather-averages-index.php">
#       States
#      </a>
#     </div>
#     <ul>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-state-temperatures.php">
#        Temperature
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-state-precipitation.php">
#        Precipitation
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/average-snowfall-by-state.php">
#        Snow
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/average-annual-state-sunshine.php">
#        Sun
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather/US/annual-average-humidity-by-state.php">
#        Humidity
#       </a>
#      </li>
#     </ul>
#     <div class="narrow-nav-subcategory">
#      <a href="/Weather-Extremes/US/index.php">
#       Extreme USA Weather
#      </a>
#     </div>
#     <ul>
#      <li class="subtopic">
#       <a href="/Weather/top-10-us-states-with-best-weather.php">
#        Best
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/coldest.php">
#        Coldest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/hottest.php">
#        Hottest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/snowiest.php">
#        Snowiest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/stormiest-cities.php">
#        Stormiest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/driest-city.php">
#        Driest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/wettest.php">
#        Wettest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/cloudiest.php">
#        Cloudiest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/windiest-cities.php">
#        Windiest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/calmest-cities.php">
#        Calmest
#       </a>
#      </li>
#      <li class="subtopic">
#       <a href="/Weather-Extremes/US/sunniest.php">
#        Sunniest
#       </a>
#      </li>
#     </ul>
#     <div class="narrow-nav-global">
#      <a href="/Weather-Extremes/index.php">
#       World Weather Extremes
#      </a>
#     </div>
#     <div class="narrow-nav-global">
#      <a href="/Weather/index.php">
#       World Weather Averages
#      </a>
#     </div>
#     <div class="narrow-nav-global">
#      <a href="/Weather/US/weather-averages-index.php">
#       USA
#      </a>
#     </div>
#     <div class="narrow-nav-global">
#      <a href="/Weather/Canada/weather-averages-index.php">
#       Canada
#      </a>
#     </div>
#     <div class="narrow-nav-global">
#      <a href="/Weather/Europe/Cities/average-european-city-weather.php">
#       Europe
#      </a>
#     </div>
#     <a class="to-top" href="#top">
#      <span class="arrow">
#       ↑
#      </span>
#      Back to Top
#     </a>
#    </div>
#    <div id="leftcol">
#     <div class="bordertopgrey">
#     </div>
#     <div class="leftcol-nav-maincategory">
#      <a href="/Weather/US/weather-averages-index.php">
#       American Weather
#      </a>
#     </div>
#     <div class="leftcol-nav-subcategory">
#      <a href="/Weather/US/average-city-weather.php">
#       Major USA Cities
#      </a>
#     </div>
#     <div class="linklist">
#      <ul>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-temperatures-large-cities.php">
#         Temperature
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-precipitation-by-city.php">
#         Precipitation
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/annual-snowfall-by-city.php">
#         Snow
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-sunshine-by-city.php">
#         Sun
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/cloud-fog-city-annual.php">
#         Cloud
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/humidity-city-annual.php">
#         Humidity
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/wind-speed-city-annual.php">
#         Wind
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Yearly-Weather/USA/recent-yearly-weather-usa-cities-index.php">
#         Recent
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="leftcol-nav-subcategory">
#      <a href="/Weather/US/weather-averages-index.php">
#       States
#      </a>
#     </div>
#     <div class="linklist">
#      <ul>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-state-temperatures.php">
#         Temperature
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-state-precipitation.php">
#         Precipitation
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/average-snowfall-by-state.php">
#         Snow
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/average-annual-state-sunshine.php">
#         Sun
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather/US/annual-average-humidity-by-state.php">
#         Humidity
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="bordertopgrey">
#     </div>
#     <div class="leftcol-nav-maincategory">
#      <a href="/Weather-Extremes/US/index.php">
#       Extreme USA Weather
#      </a>
#     </div>
#     <div class="linklist">
#      <ul>
#       <li class="subtopic">
#        <a href="/Weather/top-10-us-states-with-best-weather.php">
#         Best
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/coldest.php">
#         Coldest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/hottest.php">
#         Hottest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/driest-city.php">
#         Driest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/wettest.php">
#         Wettest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/snowiest.php">
#         Snowiest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/cloudiest.php">
#         Cloudiest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/windiest-cities.php">
#         Windiest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/calmest-cities.php">
#         Calmest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/stormiest-cities.php">
#         Stormiest
#        </a>
#       </li>
#       <li class="subtopic">
#        <a href="/Weather-Extremes/US/sunniest.php">
#         Sunniest
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="bordertopgrey">
#     </div>
#    </div>
#    <div id="sticky-ad-160">
#     <style>
#      .cr-sticky-desk-160-600-dkbl { display:none; }
# @media(min-width: 980px) { .cr-sticky-desk-160-600-dkbl { display:inline-block;width:160px;height:600px; }
#     </style>
#     <ins class="adsbygoogle cr-sticky-desk-160-600-dkbl" data-ad-client="ca-pub-8496941113728804" data-ad-slot="4039352010">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#    </div>
#    <div class="popstop">
#    </div>
#    <a name="ms">
#    </a>
#    <div class="mobile-search">
#     <script>
#      (function() {
#     var cx = 'partner-pub-8496941113728804:5136326527';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = (document.location.protocol == 'https:' ? 'https:' : 'http:') +
#         '//www.google.com/cse/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#     </script>
#     <gcse:searchbox-only>
#     </gcse:searchbox-only>
#    </div>
#    <div class="footer">
#     <p>
#      <a href="/index.php" rel="nofollow">
#       Home
#      </a>
#      |
#      <a href="/About/privacy.php" rel="nofollow">
#       Privacy &amp; Cookies
#      </a>
#      |
#      <a href="/About/contact.php" rel="nofollow">
#       Contact
#      </a>
#      |
#      <a href="/About/index.php" rel="nofollow">
#       About
#      </a>
#     </p>
#     <p>
#      <a href="/About/termsuse.php" rel="nofollow">
#       Copyright © 2020 Current Results Publishing Ltd.
#      </a>
#     </p>
#    </div>
#   </div>
#   <script src="https://cc.cdn.civiccomputing.com/8.0/cookieControl-8.0.min.js">
#   </script>
#   <script>
#    var config = {
#         apiKey: 'dd73f0e2a5b0980158e263b3194b888dc0cbaf48',
#         product: 'PRO',
#    			initialState: "NOTIFY",
#  		    position: 'LEFT',
#         theme: 'LIGHT',
#         branding: {
#             fontColor: "#333",
#             backgroundColor: "#f4f4f4",
#             toggleText: "#fff",
#             toggleColor: "#222",
#             toggleBackground: "#444",
#             buttonIcon: null,
#             buttonIconWidth: "64px",
#             buttonIconHeight: "64px",
#             removeIcon: false,
#             removeAbout: true
#         },
#
# 		text : {
# 			title: 'This site uses cookies.',
# 			intro:  'Some of these cookies are essential, while others help us to improve your experience.',
# 			necessaryTitle : 'Necessary Cookies',
# 			necessaryDescription : 'The website needs these cookies to function properly. They include Google AdSense and do not collect personal data of EU visitors. By using this website, you agree to our use of these cookies.',
# 			thirdPartyTitle : 'Warning: Some cookies require your attention',
# 			thirdPartyDescription : 'Consent for some third party cookies can not be automatically revoked. Please follow the link below if you want to opt out of them.'
# 	},
# 	  statement : {
# 			description: 'To find out more visit our',
# 			name : 'privacy policy',
# 			url: 'https://www.currentresults.com/About/privacy.php',
# 			updated : '21/05/2018'
#   },
#
#    optionalCookies: [
#             {
#                     name: 'analytics',
#                     label: 'Analytics',
#                     description: 'Analytics cookies help us improve the website and do not collect personal data.',
# 										initialConsentState : 'on',
#                     cookies: ['_ga', '_gid', '_gat', '__utma', '__utmt', '__utmb', '__utmc', '__utmz', '__utmv'],
#                     onAccept : function(){
# 											 // Add Google Analytics
#                 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                 })(window,document,'script','https://www.googletagmanager.com/gtag/js?id=UA-1038710-3','ga');
# ga('create', 'UA-1038710-3', 'auto');
#                 ga('send', 'pageview');
#                 // End Google Analytics
# },
#                     onRevoke: function(){}
#                 },{
#                     name: 'social sharing',
#                     label: 'Social Sharing',
#                     description: 'We use AddThis to help you share webpages. AddThis collects IP addresses.',
#    									initialConsentState : 'on',
#                     cookies: ['__atuvc', '__atuvs'],
#                     onAccept : function(){
# 											 // Add addThis
#                 var script = document.createElement("script");
#                 script.src = "//s7.addthis.com/js/300/addthis_widget.js#pubid=wildland";
#                 document.body.appendChild(script);
#                 // End addThis
# 								},
#                     onRevoke: function(){
# 										// Disable addThis
#                 CookieControl.delete("__atuvc");
#                 CookieControl.delete("__atuvs");
#                 // End addThis
#             },
#             thirdPartyCookies: [{"name": "AddThis", "optOutLink": "http://www.addthis.com/privacy/opt-out"}]
# }
#         ],
#
#         excludedCountries: ["all"]
#
#     };
#
#     CookieControl.load( config );
#   </script>
#  </body>
# </html>
