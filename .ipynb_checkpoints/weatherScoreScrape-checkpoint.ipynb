# %%
#import dependencies
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
#website we are scraping
url='https://wallethub.com/edu/cities-with-the-best-worst-weather/5043/'

# %%
#getting a response
response= requests.get(url)

# %%
#testing code
soup= bs(response.text, 'lxml')

# %%
#<table class="cardhub-edu-table climaterank center-aligned">
xlist = soup.find_all('table', class_="cardhub-edu-table climaterank center-aligned")[0].text.replace('\n\n\n','+')\
.replace('\n',':').split('+')

counter=0
datalist=[]
for thing in xlist[1:-1]:
    Data={}
    if counter==0:
        x= thing.split(':')
        Data[x[2]]=x[1]
        counter+=1
    else:
        x= thing.split(':')
        counter+=1
        Data[x[1]]=x[0]
    datalist.append(Data)
print(datalist)
# Out:
# {'Arden-Arcade, CA': '1'}
# {'Citrus Heights, CA': '1'}
# {'Roseville, CA': '1'}
# {'Davis, CA': '1'}
# {'Glendale, CA': '1'}
# {'Pasadena, CA': '1'}
# {'Burbank, CA': '1'}
# {'Menifee, CA': '2'}
# {'Riverside, CA': '2'}
# {'Jurupa Valley, CA': '2'}
# {'Bakersfield, CA': '2'}
# {'Hesperia, CA': '2'}
# {'Apple Valley, CA': '3'}
# {'Victorville, CA': '3'}
# {'Scottsdale, AZ': '3'}
# {'Henderson, NV': '3'}
# {'Indio, CA': '3'}
# {'Hemet, CA': '3'}
# {'Las Cruces, NM': '4'}
# {'North Las Vegas, NV': '4'}
# {'Modesto, CA': '4'}
# {'Turlock, CA': '4'}
# {'Corona, CA': '4'}
# {'Anaheim, CA': '4'}
# {'Garden Grove, CA': '4'}
# {'Fullerton, CA': '4'}
# {'Norwalk, CA': '4'}
# {'Buena Park, CA': '4'}
# {'Saint George, UT': '5'}
# {'Lancaster, CA': '5'}
# {'Palmdale, CA': '5'}
# {'Los Angeles, CA': '6'}
# {'East Los Angeles, CA': '6'}
# {'South Gate, CA': '6'}
# {'San Tan Valley, AZ': '6'}
# {'Rio Rancho, NM': '6'}
# {'Murrieta, CA': '7'}
# {'Thornton, CO': '7'}
# {'Merced, CA': '7'}
# {'Pomona, CA': '7'}
# {'Sunnyvale, CA': '7'}
# {'Mountain View, CA': '7'}
# {'San Bernardino, CA': '8'}
# {'Redlands, CA': '8'}
# {'Rialto, CA': '8'}
# {'Lynwood, CA': '8'}
# {'Inglewood, CA': '8'}
# {'Compton, CA': '8'}
# {'Hawthorne, CA': '8'}
# {'Pleasanton, CA': '9'}
# {'Livermore, CA': '9'}
# {'Chino, CA': '9'}
# {'Chino Hills, CA': '9'}
# {'San Ramon, CA': '9'}
# {'El Cajon, CA': '10'}
# {'Vacaville, CA': '10'}
# {'Visalia, CA': '10'}
# {'Folsom, CA': '10'}
# {'Elk Grove, CA': '10'}
# {'Rancho Cordova, CA': '10'}
# {'Sacramento, CA': '11'}
# {'Roswell, NM': '11'}
# {'Stockton, CA': '11'}
# {'Tracy, CA': '11'}
# {'Manteca, CA': '11'}
# {'Yuma, AZ': '11'}
# {'Boca Raton, FL': '12'}
# {'Boynton Beach, FL': '12'}
# {'Surprise, AZ': '12'}
# {'Glendale, AZ': '12'}
# {'Peoria, AZ': '12'}
# {'Longmont, CO': '12'}
# {'Midland, TX': '13'}
# {'Santa Monica, CA': '13'}
# {'Brandon, FL': '13'}
# {'Moreno Valley, CA': '13'}
# {'Perris, CA': '13'}
# {'Temecula, CA': '13'}
# {'El Monte, CA': '14'}
# {'West Covina, CA': '14'}
# {'Whittier, CA': '14'}
# {'Alhambra, CA': '14'}
# {'Baldwin Park, CA': '14'}
# {'Concord, CA': '14'}
# {'Antioch, CA': '14'}
# {'Fort Collins, CO': '15'}
# {'Greeley, CO': '15'}
# {'Loveland, CO': '15'}
# {'Long Beach, CA': '15'}
# {'Downey, CA': '15'}
# {'Carson, CA': '16'}
# {'Lakewood, CA': '16'}
# {'Bellflower, CA': '16'}
# {'Nampa, ID': '16'}
# {'Meridian, ID': '16'}
# {'Fishers, IN': '16'}
# {'Columbia, MD': '17'}
# {'Tampa, FL': '17'}
# {'Riverview, FL': '17'}
# {'Santa Fe, NM': '17'}
# {'Concord, NC': '17'}
# {'Escondido, CA': '17'}
# {'Chandler, AZ': '18'}
# {'Gilbert, AZ': '18'}
# {'Tucson, AZ': '18'}
# {'Phoenix, AZ': '18'}
# {'Tempe, AZ': '18'}
# {'Boulder, CO': '18'}
# {'Casas Adobes, AZ': '18'}
# {'Avondale, AZ': '19'}
# {'Goodyear, AZ': '19'}
# {'Palm Coast, FL': '19'}
# {'Pueblo, CO': '19'}
# {'Odessa, TX': '19'}
# {'Suffolk, VA': '20'}
# {'Thousand Oaks, CA': '20'}
# {'Torrance, CA': '20'}
# {'Redondo Beach, CA': '20'}
# {'Fontana, CA': '20'}
# {'Grand Prairie, TX': '20'}
# {'Rancho Cucamonga, CA': '20'}
# {'Ontario, CA': '20'}
# {'Upland, CA': '20'}
# {'Las Vegas, NV': '21'}
# {'Sunrise Manor, NV': '21'}
# {'Spring Valley, NV': '21'}
# {'Enterprise, NV': '21'}
# {'Yakima, WA': '22'}
# {'Oxnard, CA': '22'}
# {'Ventura, CA': '22'}
# {'Fresno, CA': '22'}
# {'Clovis, CA': '22'}
# {'Redding, CA': '23'}
# {'Johns Creek, GA': '23'}
# {'Mesa, AZ': '23'}
# {'Bend, OR': '23'}
# {'Santa Ana, CA': '23'}
# {'Irvine, CA': '23'}
# {'Orange, CA': '23'}
# {'Costa Mesa, CA': '23'}
# {'Mission Viejo, CA': '24'}
# {'Newport Beach, CA': '24'}
# {'Lake Forest, CA': '24'}
# {'Tustin, CA': '24'}
# {'Paradise, NV': '25'}
# {'Wichita Falls, TX': '25'}
# {'Provo, UT': '25'}
# {'Orem, UT': '25'}
# {'Santa Barbara, CA': '25'}
# {'Chico, CA': '25'}
# {'Huntington Beach, CA': '26'}
# {'Westminster, CA': '26'}
# {'Kennewick, WA': '26'}
# {'Redwood City, CA': '26'}
# {'Mesquite, TX': '26'}
# {'San Jose, CA': '26'}
# {'Santa Clara, CA': '26'}
# {'Milpitas, CA': '27'}
# {'Charleston, SC': '27'}
# {'Beaumont, TX': '27'}
# {'Silver Spring, MD': '27'}
# {'Fremont, CA': '27'}
# {'Carlsbad, CA': '28'}
# {'Vista, CA': '28'}
# {'San Angelo, TX': '28'}
# {'San Marcos, CA': '28'}
# {'Union City, CA': '28'}
# {'Hayward, CA': '28'}
# {'El Paso, TX': '29'}
# {'Mount Pleasant, SC': '29'}
# {'Fairfield, CA': '29'}
# {'West Valley, UT': '29'}
# {'West Jordan, UT': '29'}
# {'Sandy, UT': '29'}
# {'Columbia, SC': '30'}
# {'Huntsville, AL': '30'}
# {'Boise, ID': '30'}
# {'Oceanside, CA': '30'}
# {'Lake Charles, LA': '30'}
# {'Flagstaff, AZ': '30'}
# {'Lehigh Acres, FL': '31'}
# {'Cape Coral, FL': '31'}
# {'Portsmouth, VA': '31'}
# {'Kearney, NE': '31'}
# {'Gastonia, NC': '31'}
# {'Ogden, UT': '31'}
# {'Spring Hill, FL': '32'}
# {'Norman, OK': '32'}
# {'Reno, NV': '32'}
# {'Sparks, NV': '32'}
# {'Abilene, TX': '32'}
# {'Orlando, FL': '32'}
# {'Alafaya, FL': '32'}
# {'Chula Vista, CA': '33'}
# {'Tulsa, OK': '33'}
# {'Broken Arrow, OK': '33'}
# {'Greenville, NC': '33'}
# {'Santa Rosa, CA': '33'}
# {'Deltona, FL': '34'}
# {'Germantown, MD': '34'}
# {'Denton, TX': '34'}
# {'Laredo, TX': '34'}
# {'Fort Worth, TX': '34'}
# {'Pembroke Pines, FL': '34'}
# {'Miramar, FL': '34'}
# {'Davie, FL': '34'}
# {'Weston, FL': '34'}
# {'Rock Hill, SC': '35'}
# {'Garland, TX': '35'}
# {'San Diego, CA': '35'}
# {'Santa Clarita, CA': '36'}
# {'Simi Valley, CA': '36'}
# {'Joliet, IL': '36'}
# {'Oklahoma City, OK': '36'}
# {'Edmond, OK': '36'}
# {'Jackson, MS': '36'}
# {'Edinburg, TX': '37'}
# {'McKinney, TX': '37'}
# {'Allen, TX': '37'}
# {'Casper, WY': '37'}
# {'Vallejo, CA': '37'}
# {'Napa, CA': '37'}
# {'Hoover, AL': '38'}
# {'Augusta, GA': '38'}
# {'Arlington, TX': '38'}
# {'Albuquerque, NM': '38'}
# {'Gainesville, FL': '38'}
# {'Hialeah, FL': '38'}
# {'Miami Gardens, FL': '38'}
# {'Medford, OR': '39'}
# {'Albany, GA': '39'}
# {'Winston-Salem, NC': '39'}
# {'Independence, MO': '39'}
# {'Salinas, CA': '39'}
# {'Lynchburg, VA': '40'}
# {'McAllen, TX': '40'}
# {'Saint Petersburg, FL': '40'}
# {'Mission, TX': '40'}
# {'Pharr, TX': '40'}
# {'Rock Springs, WY': '40'}
# {'Rochester, MI': '41'}
# {'Sterling Heights, MI': '41'}
# {'Troy, MI': '41'}
# {'Southfield, MI': '41'}
# {'Athens-Clarke, GA': '41'}
# {'Macon, GA': '41'}
# {'Shreveport, LA': '42'}
# {'Fort Smith, AR': '42'}
# {'Lakeland, FL': '42'}
# {'Columbus, GA': '42'}
# {'Clearwater, FL': '42'}
# {'Largo, FL': '42'}
# {'Atlanta, GA': '43'}
# {'Sandy Springs, GA': '43'}
# {'Tuscaloosa, AL': '43'}
# {'Amarillo, TX': '43'}
# {'Palm Bay, FL': '43'}
# {'Melbourne, FL': '43'}
# {'Temple, TX': '44'}
# {'Santa Maria, CA': '44'}
# {'Missouri City, TX': '44'}
# {'Overland Park, KS': '44'}
# {'Kansas City, KS': '44'}
# {'Colorado Springs, CO': '44'}
# {'Honolulu, HI': '45'}
# {'Pearl City, HI': '45'}
# {'East Honolulu, HI': '45'}
# {'Kansas City, MO': '45'}
# {'Topeka, KS': '45'}
# {'Plano, TX': '45'}
# {'Frisco, TX': '45'}
# {'Carrollton, TX': '45'}
# {'Richardson, TX': '45'}
# {'Fayetteville, AR': '46'}
# {'Rapid City, SD': '46'}
# {'Dothan, AL': '46'}
# {'Gillette, WY': '47'}
# {'Longview, TX': '47'}
# {'Pearland, TX': '47'}
# {'Schenectady, NY': '47'}
# {'Woonsocket, RI': '47'}
# {'Pawtucket, RI': '47'}
# {'Toms River, NJ': '47'}
# {'Brookings, SD': '48'}
# {'Fayetteville, NC': '48'}
# {'Gulfport, MS': '48'}
# {'Kendall, FL': '48'}
# {'Lawrence, KS': '48'}
# {'Sugar Land, TX': '49'}
# {'Lincoln, NE': '49'}
# {'Saint Charles, MO': '49'}
# {'Frederick, MD': '49'}
# {'Round Rock, TX': '49'}
# {'Tyler, TX': '49'}
# {'The Woodlands, TX': '50'}
# {'Bolingbrook, IL': '50'}
# {'Brownsville, TX': '50'}
# {'Waco, TX': '50'}
# {'Jackson, TN': '50'}
# {'Lafayette, LA': '50'}
# {'Wilmington, NC': '51'}
# {'Grand Island, NE': '51'}
# {'Killeen, TX': '51'}
# {'Trenton, NJ': '51'}
# {'Owensboro, KY': '51'}
# {'Hattiesburg, MS': '51'}
# {'Carmel, IN': '52'}
# {'Allentown, PA': '52'}
# {'Lees Summit, MO': '52'}
# {'Saint Joseph, MO': '52'}
# {'Jonesboro, AR': '52'}
# {'Pocatello, ID': '52'}
# {'Chesapeake, VA': '53'}
# {'Clarksville, TN': '53'}
# {'Bryan, TX': '53'}
# {'College Station, TX': '53'}
# {'Lubbock, TX': '53'}
# {'Lakewood, CO': '53'}
# {'Arvada, CO': '53'}
# {'Westminster, CO': '53'}
# {'Olathe, KS': '54'}
# {'Lewiston, ME': '54'}
# {'Auburn, ME': '54'}
# {'Great Falls, MT': '54'}
# {'Mobile, AL': '55'}
# {'Waukesha, WI': '55'}
# {'Springdale, AR': '55'}
# {'Coral Springs, FL': '55'}
# {'Sunrise, FL': '55'}
# {'Lauderhill, FL': '55'}
# {'Baytown, TX': '56'}
# {'Pasadena, TX': '56'}
# {'League City, TX': '56'}
# {'Paterson, NJ': '56'}
# {'Warner Robins, GA': '56'}
# {'Roanoke, VA': '56'}
# {'Newport News, VA': '57'}
# {'Evansville, IN': '57'}
# {'Laramie, WY': '57'}
# {'Sioux City, IA': '57'}
# {'O Fallon, MO': '57'}
# {'San Francisco, CA': '57'}
# {'San Mateo, CA': '57'}
# {'Daly City, CA': '57'}
# {'Rochester, MN': '58'}
# {'Lawton, OK': '58'}
# {'Spokane, WA': '58'}
# {'Spokane Valley, WA': '58'}
# {'Savannah, GA': '59'}
# {"Town 'n' Country, FL": '59'}
# {'Bowling Green, KY': '59'}
# {'Columbia, MO': '59'}
# {'Springfield, IL': '59'}
# {'North Charleston, SC': '59'}
# {'Bozeman, MT': '60'}
# {'Peoria, IL': '60'}
# {'Bismarck, ND': '60'}
# {'Toledo, OH': '60'}
# {'Iowa City, IA': '60'}
# {'San Leandro, CA': '60'}
# {'Alameda, CA': '60'}
# {'Cheyenne, WY': '61'}
# {'Oakland, CA': '61'}
# {'Berkeley, CA': '61'}
# {'Richmond, CA': '61'}
# {'Reading, PA': '61'}
# {'Lafayette, IN': '62'}
# {'Philadelphia, PA': '62'}
# {'Butte, MT': '62'}
# {'Palatine, IL': '62'}
# {'Nashua, NH': '62'}
# {'Arlington Heights, IL': '62'}
# {'Evanston, IL': '62'}
# {'Springfield, MO': '63'}
# {'Idaho Falls, ID': '63'}
# {'Newark, DE': '63'}
# {'Bear, DE': '63'}
# {'Middletown, DE': '63'}
# {'Wilmington, DE': '63'}
# {'Aberdeen, SD': '64'}
# {'New Orleans, LA': '64'}
# {'Metairie, LA': '64'}
# {'Montgomery, AL': '64'}
# {'Murfreesboro, TN': '64'}
# {'Baton Rouge, LA': '65'}
# {'Decatur, IL': '65'}
# {'Davenport, IA': '65'}
# {'Port Saint Lucie, FL': '65'}
# {'New York, NY': '65'}
# {'Jersey City, NJ': '65'}
# {'Union City, NJ': '65'}
# {'Hartford, CT': '66'}
# {'New Britain, CT': '66'}
# {'Huntington, WV': '66'}
# {'Vancouver, WA': '66'}
# {'Tallahassee, FL': '66'}
# {'Missoula, MT': '67'}
# {'High Point, NC': '67'}
# {'Passaic, NJ': '67'}
# {'Clifton, NJ': '67'}
# {'Greensboro, NC': '67'}
# {'Cincinnati, OH': '67'}
# {'Covington, KY': '67'}
# {'Duluth, MN': '68'}
# {'Bloomington, IN': '68'}
# {'Pompano Beach, FL': '68'}
# {'Deerfield Beach, FL': '68'}
# {'Parkersburg, WV': '68'}
# {'Birmingham, AL': '69'}
# {'Danbury, CT': '69'}
# {'Detroit, MI': '69'}
# {'Warren, MI': '69'}
# {'Dearborn, MI': '69'}
# {'Waterbury, CT': '69'}
# {'Cedar Rapids, IA': '70'}
# {'Lowell, MA': '70'}
# {'Lawrence, MA': '70'}
# {'Asheville, NC': '70'}
# {'New Haven, CT': '70'}
# {'Brockton, MA': '70'}
# {'Quincy, MA': '70'}
# {'Columbus, OH': '71'}
# {'Aurora, IL': '71'}
# {'Naperville, IL': '71'}
# {'Elgin, IL': '71'}
# {'Billings, MT': '71'}
# {'Rutland, VT': '72'}
# {'Lexington, KY': '72'}
# {'Norfolk, VA': '72'}
# {'Fort Lauderdale, FL': '72'}
# {'Hollywood, FL': '72'}
# {'Plantation, FL': '72'}
# {'Dale City, VA': '73'}
# {'Jacksonville, NC': '73'}
# {'Renton, WA': '73'}
# {'Champaign, IL': '73'}
# {'Dover, NH': '73'}
# {'Rochester, NH': '73'}
# {'Centennial, CO': '74'}
# {'Highlands Ranch, CO': '74'}
# {'Denver, CO': '74'}
# {'Manchester, NH': '74'}
# {'Salt Lake City, UT': '74'}
# {'Aurora, CO': '74'}
# {'Bridgeport, CT': '75'}
# {'Corpus Christi, TX': '75'}
# {'Racine, WI': '75'}
# {'Watertown, SD': '75'}
# {'Hillsboro, OR': '75'}
# {'Beaverton, OR': '75'}
# {'Jacksonville, FL': '76'}
# {'Kailua, HI': '76'}
# {'Bethlehem, PA': '76'}
# {'Hammond, IN': '76'}
# {'Gary, IN': '76'}
# {'Roswell, GA': '76'}
# {'Ann Arbor, MI': '77'}
# {'Chattanooga, TN': '77'}
# {'Muncie, IN': '77'}
# {'Layton, UT': '77'}
# {'Oshkosh, WI': '77'}
# {'Kenosha, WI': '77'}
# {'Waukegan, IL': '78'}
# {'Salem, OR': '78'}
# {'Minot, ND': '78'}
# {'Newton, MA': '78'}
# {'Biloxi, MS': '78'}
# {'Bloomington, IL': '78'}
# {'Framingham, MA': '79'}
# {'West Fargo, ND': '79'}
# {'Fargo, ND': '79'}
# {'Sioux Falls, SD': '79'}
# {'Saint Cloud, MN': '79'}
# {'Miami, FL': '79'}
# {'Miami Beach, FL': '79'}
# {'Appleton, WI': '80'}
# {'Akron, OH': '80'}
# {'Saint Paul, MN': '80'}
# {'Waterloo, IA': '80'}
# {'Seattle, WA': '80'}
# {'Bellevue, WA': '80'}
# {'Hilo, HI': '81'}
# {'Morgantown, WV': '81'}
# {'Charlotte, NC': '81'}
# {'Charleston, WV': '81'}
# {'West Palm Beach, FL': '81'}
# {'Dallas, TX': '82'}
# {'Bellevue, NE': '82'}
# {'Fairbanks, AK': '82'}
# {'Wheeling, WV': '82'}
# {'Green Bay, WI': '82'}
# {'Eau Claire, WI': '82'}
# {'Knoxville, TN': '83'}
# {'Madison, WI': '83'}
# {'Gresham, OR': '83'}
# {'San Antonio, TX': '83'}
# {'Omaha, NE': '83'}
# {'Irving, TX': '83'}
# {'Lewisville, TX': '83'}
# {'Flower Mound, TX': '83'}
# {'Minneapolis, MN': '84'}
# {'Portland, OR': '84'}
# {'Brooklyn Park, MN': '84'}
# {'Plymouth, MN': '84'}
# {'Scranton, PA': '85'}
# {'Hampton, VA': '85'}
# {'Raleigh, NC': '85'}
# {'Durham, NC': '85'}
# {'Cary, NC': '85'}
# {'Kalamazoo, MI': '85'}
# {'New Bedford, MA': '86'}
# {'Fall River, MA': '86'}
# {'South Bend, IN': '86'}
# {'Eugene, OR': '86'}
# {'Austin, TX': '86'}
# {'Anchorage, AK': '86'}
# {'Cleveland, OH': '87'}
# {'Concord, NH': '87'}
# {'Atascocita, TX': '87'}
# {'Pittsburgh, PA': '87'}
# {'Tacoma, WA': '87'}
# {'South Portland, ME': '87'}
# {'Portland, ME': '87'}
# {'Norwalk, CT': '88'}
# {'Stamford, CT': '88'}
# {'Little Rock, AR': '88'}
# {'Waldorf, MD': '88'}
# {'Kenner, LA': '88'}
# {'Dover, DE': '89'}
# {'Flint, MI': '89'}
# {'Wichita, KS': '89'}
# {'Houston, TX': '89'}
# {'Memphis, TN': '89'}
# {'Southaven, MS': '89'}
# {'Bellingham, WA': '90'}
# {'Nashville, TN': '90'}
# {'Springfield, MA': '90'}
# {'Everett, WA': '90'}
# {'Centreville, VA': '90'}
# {'Richmond, VA': '90'}
# {'Erie, PA': '91'}
# {'Albany, NY': '91'}
# {'Baltimore, MD': '91'}
# {'Ellicott City, MD': '91'}
# {'Glen Burnie, MD': '91'}
# {'Grand Forks, ND': '91'}
# {'Virginia Beach, VA': '92'}
# {'Louisville, KY': '92'}
# {'Chicago, IL': '92'}
# {'Cicero, IL': '92'}
# {'Farmington, MI': '92'}
# {'Auburn, WA': '92'}
# {'Kent, WA': '92'}
# {'Federal Way, WA': '92'}
# {'Washington, DC': '93'}
# {'Arlington, VA': '93'}
# {'Alexandria, VA': '93'}
# {'Saint Louis, MO': '93'}
# {'Westland, MI': '94'}
# {'Montpelier, VT': '94'}
# {'Barre, VT': '94'}
# {'Livonia, MI': '94'}
# {'Des Moines, IA': '94'}
# {'Dayton, OH': '94'}
# {'Worcester, MA': '95'}
# {'Camden, NJ': '95'}
# {'Bloomington, MN': '95'}
# {'Schaumburg, IL': '95'}
# {'Milwaukee, WI': '95'}
# {'Winooski, VT': '95'}
# {'Burlington, VT': '95'}
# {'Yonkers, NY': '96'}
# {'New Rochelle, NY': '96'}
# {'Mount Vernon, NY': '96'}
# {'Bangor, ME': '96'}
# {'Rockford, IL': '96'}
# {'Fort Wayne, IN': '97'}
# {'Lansing, MI': '97'}
# {'Newark, NJ': '97'}
# {'Elizabeth, NJ': '97'}
# {'Parma, OH': '97'}
# {'Grand Rapids, MI': '97'}
# {'Boston, MA': '98'}
# {'Cambridge, MA': '98'}
# {'Lynn, MA': '98'}
# {'Somerville, MA': '98'}
# {'Wyoming, MI': '98'}
# {'Indianapolis, IN': '98'}
# {'Providence, RI': '99'}
# {'Warwick, RI': '99'}
# {'Cranston, RI': '99'}
# {'Rochester, NY': '99'}
# {'Canton, OH': '99'}
# {'Buffalo, NY': '99'}
# {'Cheektowaga, NY': '99'}
# {'Syracuse, NY': '100'}
# {'Youngstown, OH': '100'}
# {'Ketchikan, AK': '100'}
# {'Sitka, AK': '100'}
# {'Juneau, AK': '100'}

# %%
print(Data['Roseville, CA'])
# Out:
# 1

# %%
pd.read_json(Data, orient='records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-542332918c54> in <module>
# ----> 1 pd.read_json(Data, orient='records')
#
# c:\users\dcmil\anaconda3\envs\pythondata\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     567     compression = _infer_compression(path_or_buf, compression)
#     568     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 569         path_or_buf, encoding=encoding, compression=compression
#     570     )
#     571
#
# c:\users\dcmil\anaconda3\envs\pythondata\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     222     if not is_file_like(filepath_or_buffer):
#     223         msg = "Invalid file path or buffer object type: {_type}"
# --> 224         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     225
#     226     return filepath_or_buffer, None, compression, False
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>
